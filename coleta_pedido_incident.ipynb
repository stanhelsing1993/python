# %% [markdown]
# <a href="https://colab.research.google.com/github/stanhelsing1993/python/blob/main/coleta_pedido_incident.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
import re

# %%
# Substitua 'caminho/do/arquivo.xlsx' pelo caminho real do seu arquivo Excel
df = pd.read_csv('/content/Panel Title-data-25_07_2023, 14_15_51.csv', encoding= 'utf8')
#df = pd.read_excel('/content/Incident details.xlsx')

# %%
df.head()
# Out:
#           Entry ID     Submitter           Submit Date Assignee Login ID  \
# 0  INC000000009631     OISERVICO  07/07/2023, 14:42:27          VT410336
# 1  INC000000009522  hannah_admin  07/07/2023, 15:13:56          VT410336
# 2  INC000000009526  hannah_admin  07/07/2023, 15:42:21               NaN
# 3  INC000000009495     OISERVICO  07/07/2023, 17:13:22               NaN
# 4  INC000000009496     OISERVICO  07/07/2023, 17:13:29               NaN
#
#   Last Modified By    Last Modified Date     Status Short Description  \
# 0         VT410336  17/07/2023, 11:01:59  Designado                 .
# 1         VT410336  17/07/2023, 11:01:54  Designado                 .
# 2     AR_ESCALATOR  12/07/2023, 03:43:00  Designado                 .
# 3     AR_ESCALATOR  12/07/2023, 05:15:04  Designado                 .
# 4     AR_ESCALATOR  12/07/2023, 05:15:04  Designado                 .
#
#   Notifier Listening  Vendor Name  ...       SRMS Registry Instance ID  \
# ...

# %%
df_clone =  df[:]

# %%
df_final = df_clone [['Incident Number', 'Status', 'Detailed Decription','Product Name', 'Assignee', 'Assigned Group']]

# %%
df_final.head()
# Out:
#    Incident Number     Status  \
# 0  INC000000010401  Designado
# 1  INC000000010054  Designado
# 2  INC000000010059  Designado
# 3  INC000000010525  Designado
# 4  INC000000010526  Designado
#
#                                  Detailed Decription Product Name  \
# 0  Equipe SOM, o pedido já está concluído no CRM/...          NaN
# 1  "Favor verificar o motivo da divergência. Stat...          SOM
# 2  Reference # : 00910649\nOrder ID : 6062446\nAC...          SOM
# 3  Comando de desbloqueio travado aguardando reto...          NaN
# 4  Comando de desbloqueio travado aguardando reto...          NaN
#
#        Assignee Assigned Group
# 0  JOAO P MATOS       FIBRA_N1
# 1  JOAO P MATOS       FIBRA_N1
# 2           NaN       FIBRA_N1
# 3           NaN       FIBRA_N1
# 4           NaN       FIBRA_N1

# %%
padrao_regex = r'\b4-\d{12}\b'

# %%
def apply_regex(texto, regex_pattern):
    matches = re.findall(regex_pattern, texto)
    return ', '.join(matches) if matches else None

# Padrão regex
padrao_regex = r'\b4-\d{12}\b'

# Converte os valores da coluna 'X' para strings
df_final['Descrição'] = df_final['Detailed Decription'].astype(str)

# Aplica a função 'apply_regex' na coluna 'X' e salva os resultados na nova coluna 'Resultado'
df_final['pedido'] = df_final['Descrição'].apply(lambda texto: apply_regex(texto, padrao_regex))
# Out:
# <ipython-input-10-fd122b67f6e0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Descrição'] = df_final['Detailed Decription'].astype(str)
# <ipython-input-10-fd122b67f6e0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['pedido'] = df_final['Descrição'].apply(lambda texto: apply_regex(texto, padrao_regex))

# %%
df_final.head()
# Out:
#    Incident Number     Status  \
# 0  INC000000010401  Designado
# 1  INC000000010054  Designado
# 2  INC000000010059  Designado
# 3  INC000000010525  Designado
# 4  INC000000010526  Designado
#
#                                  Detailed Decription Product Name  \
# 0  Equipe SOM, o pedido já está concluído no CRM/...          NaN
# 1  "Favor verificar o motivo da divergência. Stat...          SOM
# 2  Reference # : 00910649\nOrder ID : 6062446\nAC...          SOM
# 3  Comando de desbloqueio travado aguardando reto...          NaN
# 4  Comando de desbloqueio travado aguardando reto...          NaN
#
#        Assignee Assigned Group  \
# 0  JOAO P MATOS       FIBRA_N1
# 1  JOAO P MATOS       FIBRA_N1
# 2           NaN       FIBRA_N1
# 3           NaN       FIBRA_N1
# 4           NaN       FIBRA_N1
#
#                                            Descrição pedido
# 0  Equipe SOM, o pedido já está concluído no CRM/...   None
# 1  "Favor verificar o motivo da divergência. Stat...   None
# ...

# %%
df_final.to_excel('/content/INCIDENTES.xlsx', index=False)
